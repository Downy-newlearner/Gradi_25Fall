# %%
import os
import csv
import base64
import re
import ast
from dotenv import load_dotenv
from groq import Groq

load_dotenv()

def split_top_level_commas(s):
    """
    대괄호 레벨을 고려해서 top-level 쉼표 기준으로 분리
    """
    parts = []
    current = ''
    level = 0
    for c in s:
        if c == '[':
            level += 1
            current += c
        elif c == ']':
            level -= 1
            current += c
        elif c == ',' and level == 0:
            parts.append(current.strip())
            current = ''
        else:
            current += c
    if current:
        parts.append(current.strip())
    return parts

def parse_problem_info(input_str):
    """
    annotation.txt 한 줄 파싱
    """
    # 파일명 부분과 나머지 분리
    top_level_parts = split_top_level_commas(input_str)
    if len(top_level_parts) < 4:
        raise ValueError(f"형식 오류: {input_str}")

    file_part = top_level_parts[0]
    problem_number = int(top_level_parts[1])
    type_str = top_level_parts[2]
    answer_str = ','.join(top_level_parts[3:])  # 나머지는 answer로 합침

    # 파일명 파싱
    file_match = re.match(r"(.+?) - (\d+)_section_(\d+)_conf[\d.]+\.jpg", file_part)
    if not file_match:
        raise ValueError(f"파일명 형식 오류: {file_part}")

    book = file_match.group(1)
    page = int(file_match.group(2))
    section_number = int(file_match.group(3))

    # type과 answer 변환
    def parse_sub_question(s):
        s = s.strip()
        if s.startswith('[') and s.endswith(']'):
            s_inner = s[1:-1]
            items = split_top_level_commas(s_inner)
            result = {}
            for item in items:
                if ':' in item:
                    key, value = item.split(':', 1)
                    key, value = key.strip(), value.strip()
                    if value.startswith('[') and value.endswith(']'):
                        value = ast.literal_eval(value)
                    else:
                        try:
                            value = int(value)
                        except:
                            pass
                    result[key] = value
                else:
                    try:
                        return ast.literal_eval("[" + s_inner + "]")
                    except:
                        return s_inner
            return result
        else:
            return s

    return {
        "file": file_part,
        "book": book,
        "page": page,
        "section_number": section_number,
        "problem_number": problem_number,
        "type": type_str,
        "answer": answer_str
    }

def compare_answer(pred, gold):
    """모델 응답과 실제 정답 비교"""
    try:
        return str(pred).strip() == str(gold).strip()
    except:
        return False

def load_annotation_dict(annotation_file):
    """annotation.txt 파일을 {파일명: info} dict로 변환"""
    mapping = {}
    with open(annotation_file, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = [p.strip() for p in line.split(',', 3)]
            if len(parts) < 4 or not parts[1].isdigit():
                continue
            info = parse_problem_info(line)
            mapping[os.path.basename(info["file"])] = info
    return mapping

# %%
ann1 = load_annotation_dict("../../images/LLM_annotation/annotation.txt")
ann1
# Out:
# {'라이트쎈 중등수학 1-1 - 1_section_00_conf0.61.jpg': {'file': '라이트쎈 중등수학 1-1 - 1_section_00_conf0.61.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 1,
#   'section_number': 0,
#   'problem_number': 62,
#   'type': '1',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 1_section_01_conf0.55.jpg': {'file': '라이트쎈 중등수학 1-1 - 1_section_01_conf0.55.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 1,
#   'section_number': 1,
#   'problem_number': 63,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 1_section_02_conf0.51.jpg': {'file': '라이트쎈 중등수학 1-1 - 1_section_02_conf0.51.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 1,
#   'section_number': 2,
#   'problem_number': 61,
#   'type': '1',
#   'answer': '10'},
#  '라이트쎈 중등수학 1-1 - 1_section_03_conf0.46.jpg': {'file': '라이트쎈 중등수학 1-1 - 1_section_03_conf0.46.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 1,
#   'section_number': 3,
#   'problem_number': 65,
#   'type': '0',
#   'answer': '[3,4]'},
#  '라이트쎈 중등수학 1-1 - 1_section_04_conf0.44.jpg': {'file': '라이트쎈 중등수학 1-1 - 1_section_04_conf0.44.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 1,
#   'section_number': 4,
#   'problem_number': 64,
#   'type': '[1:1, 2:1, 3:1]',
#   'answer': '[1:7, 2:11, 3:[8,9,10,11]]'},
#  '라이트쎈 중등수학 1-1 - 2_section_00_conf0.71.jpg': {'file': '라이트쎈 중등수학 1-1 - 2_section_00_conf0.71.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 2,
#   'section_number': 0,
#   'problem_number': 69,
#   'type': '1',
#   'answer': '[a:5, b:6]'},
#  '라이트쎈 중등수학 1-1 - 2_section_01_conf0.64.jpg': {'file': '라이트쎈 중등수학 1-1 - 2_section_01_conf0.64.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 2,
#   'section_number': 1,
#   'problem_number': 71,
#   'type': '1',
#   'answer': '128'},
#  '라이트쎈 중등수학 1-1 - 2_section_02_conf0.62.jpg': {'file': '라이트쎈 중등수학 1-1 - 2_section_02_conf0.62.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 2,
#   'section_number': 2,
#   'problem_number': 72,
#   'type': '1',
#   'answer': '12'},
#  '라이트쎈 중등수학 1-1 - 2_section_03_conf0.44.jpg': {'file': '라이트쎈 중등수학 1-1 - 2_section_03_conf0.44.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 2,
#   'section_number': 3,
#   'problem_number': 70,
#   'type': '1',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 3_section_00_conf0.71.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_00_conf0.71.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 0,
#   'problem_number': 80,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 3_section_01_conf0.63.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_01_conf0.63.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 1,
#   'problem_number': 76,
#   'type': '1',
#   'answer': '7'},
#  '라이트쎈 중등수학 1-1 - 3_section_02_conf0.52.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_02_conf0.52.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 2,
#   'problem_number': 73,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 3_section_03_conf0.50.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_03_conf0.50.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 3,
#   'problem_number': 74,
#   'type': '1',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 3_section_04_conf0.47.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_04_conf0.47.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 4,
#   'problem_number': 75,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 3_section_05_conf0.32.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_05_conf0.32.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 5,
#   'problem_number': 77,
#   'type': '0',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 3_section_06_conf0.30.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_06_conf0.30.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 6,
#   'problem_number': 78,
#   'type': '1',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 3_section_07_conf0.28.jpg': {'file': '라이트쎈 중등수학 1-1 - 3_section_07_conf0.28.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 3,
#   'section_number': 7,
#   'problem_number': 79,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 4_section_00_conf0.79.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_00_conf0.79.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 0,
#   'problem_number': 88,
#   'type': '0',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 4_section_01_conf0.62.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_01_conf0.62.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 1,
#   'problem_number': 86,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 4_section_02_conf0.61.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_02_conf0.61.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 2,
#   'problem_number': 85,
#   'type': '1',
#   'answer': '10'},
#  '라이트쎈 중등수학 1-1 - 4_section_03_conf0.57.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_03_conf0.57.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 3,
#   'problem_number': 87,
#   'type': '[1:2, 2:1]',
#   'answer': '[1: 2*3^2*5^2*7, 2: 14]'},
#  '라이트쎈 중등수학 1-1 - 4_section_04_conf0.44.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_04_conf0.44.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 4,
#   'problem_number': 81,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 4_section_05_conf0.38.jpg': {'file': '라이트쎈 중등수학 1-1 - 4_section_05_conf0.38.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 4,
#   'section_number': 5,
#   'problem_number': 88,
#   'type': '0',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 5_section_00_conf0.70.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_00_conf0.70.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 0,
#   'problem_number': 91,
#   'type': '1',
#   'answer': '8'},
#  '라이트쎈 중등수학 1-1 - 5_section_01_conf0.70.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_01_conf0.70.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 1,
#   'problem_number': 93,
#   'type': '1',
#   'answer': '[3, 4]'},
#  '라이트쎈 중등수학 1-1 - 5_section_02_conf0.66.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_02_conf0.66.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 2,
#   'problem_number': 90,
#   'type': '1',
#   'answer': '12'},
#  '라이트쎈 중등수학 1-1 - 5_section_03_conf0.60.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_03_conf0.60.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 3,
#   'problem_number': 89,
#   'type': '1',
#   'answer': '21'},
#  '라이트쎈 중등수학 1-1 - 5_section_04_conf0.59.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_04_conf0.59.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 4,
#   'problem_number': 92,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 5_section_06_conf0.36.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_06_conf0.36.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 6,
#   'problem_number': 94,
#   'type': '0',
#   'answer': '[1,4]'},
#  '라이트쎈 중등수학 1-1 - 5_section_07_conf0.29.jpg': {'file': '라이트쎈 중등수학 1-1 - 5_section_07_conf0.29.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 5,
#   'section_number': 7,
#   'problem_number': 96,
#   'type': '1',
#   'answer': '248'},
#  '라이트쎈 중등수학 1-1 - 6_section_00_conf0.72.jpg': {'file': '라이트쎈 중등수학 1-1 - 6_section_00_conf0.72.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 6,
#   'section_number': 0,
#   'problem_number': 102,
#   'type': '0',
#   'answer': '[2,4]'},
#  '라이트쎈 중등수학 1-1 - 6_section_01_conf0.63.jpg': {'file': '라이트쎈 중등수학 1-1 - 6_section_01_conf0.63.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 6,
#   'section_number': 1,
#   'problem_number': 99,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 6_section_02_conf0.48.jpg': {'file': '라이트쎈 중등수학 1-1 - 6_section_02_conf0.48.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 6,
#   'section_number': 2,
#   'problem_number': 103,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 6_section_03_conf0.47.jpg': {'file': '라이트쎈 중등수학 1-1 - 6_section_03_conf0.47.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 6,
#   'section_number': 3,
#   'problem_number': 101,
#   'type': '3',
#   'answer': '[ㄷ, ㄹ]'},
#  '라이트쎈 중등수학 1-1 - 6_section_04_conf0.27.jpg': {'file': '라이트쎈 중등수학 1-1 - 6_section_04_conf0.27.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 6,
#   'section_number': 4,
#   'problem_number': 98,
#   'type': '1',
#   'answer': '42'},
#  '라이트쎈 중등수학 1-1 - 7_section_00_conf0.60.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_00_conf0.60.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 0,
#   'problem_number': 104,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 7_section_01_conf0.60.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_01_conf0.60.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 1,
#   'problem_number': 110,
#   'type': '1',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 7_section_02_conf0.54.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_02_conf0.54.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 2,
#   'problem_number': 105,
#   'type': '1',
#   'answer': '6'},
#  '라이트쎈 중등수학 1-1 - 7_section_03_conf0.48.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_03_conf0.48.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 3,
#   'problem_number': 109,
#   'type': '3',
#   'answer': '[ㄱ,ㄴ,ㄷ]'},
#  '라이트쎈 중등수학 1-1 - 7_section_04_conf0.43.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_04_conf0.43.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 4,
#   'problem_number': 106,
#   'type': '1',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 7_section_05_conf0.43.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_05_conf0.43.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 5,
#   'problem_number': 108,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 7_section_06_conf0.36.jpg': {'file': '라이트쎈 중등수학 1-1 - 7_section_06_conf0.36.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 7,
#   'section_number': 6,
#   'problem_number': 107,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 8_section_00_conf0.78.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_00_conf0.78.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 0,
#   'problem_number': 115,
#   'type': '1',
#   'answer': '8'},
#  '라이트쎈 중등수학 1-1 - 8_section_01_conf0.71.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_01_conf0.71.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 1,
#   'problem_number': 111,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 8_section_02_conf0.68.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_02_conf0.68.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 2,
#   'problem_number': 114,
#   'type': '1',
#   'answer': '131'},
#  '라이트쎈 중등수학 1-1 - 8_section_03_conf0.61.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_03_conf0.61.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 3,
#   'problem_number': 116,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 8_section_04_conf0.48.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_04_conf0.48.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 4,
#   'problem_number': 118,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 8_section_05_conf0.44.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_05_conf0.44.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 5,
#   'problem_number': 113,
#   'type': '1',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 8_section_06_conf0.43.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_06_conf0.43.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 6,
#   'problem_number': 117,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 8_section_07_conf0.29.jpg': {'file': '라이트쎈 중등수학 1-1 - 8_section_07_conf0.29.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 8,
#   'section_number': 7,
#   'problem_number': 112,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 9_section_00_conf0.54.jpg': {'file': '라이트쎈 중등수학 1-1 - 9_section_00_conf0.54.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 9,
#   'section_number': 0,
#   'problem_number': 119,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 9_section_01_conf0.52.jpg': {'file': '라이트쎈 중등수학 1-1 - 9_section_01_conf0.52.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 9,
#   'section_number': 1,
#   'problem_number': 121,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 9_section_02_conf0.45.jpg': {'file': '라이트쎈 중등수학 1-1 - 9_section_02_conf0.45.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 9,
#   'section_number': 2,
#   'problem_number': 120,
#   'type': '1',
#   'answer': '20'},
#  '라이트쎈 중등수학 1-1 - 9_section_03_conf0.44.jpg': {'file': '라이트쎈 중등수학 1-1 - 9_section_03_conf0.44.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 9,
#   'section_number': 3,
#   'problem_number': 122,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 10_section_00_conf0.50.jpg': {'file': '라이트쎈 중등수학 1-1 - 10_section_00_conf0.50.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 10,
#   'section_number': 0,
#   'problem_number': 133,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 10_section_01_conf0.34.jpg': {'file': '라이트쎈 중등수학 1-1 - 10_section_01_conf0.34.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 10,
#   'section_number': 1,
#   'problem_number': 127,
#   'type': '1',
#   'answer': '18'},
#  '라이트쎈 중등수학 1-1 - 10_section_02_conf0.31.jpg': {'file': '라이트쎈 중등수학 1-1 - 10_section_02_conf0.31.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 10,
#   'section_number': 2,
#   'problem_number': 126,
#   'type': '1',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 11_section_00_conf0.55.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_00_conf0.55.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 0,
#   'problem_number': 184,
#   'type': '0',
#   'answer': '[2,5]'},
#  '라이트쎈 중등수학 1-1 - 11_section_01_conf0.52.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_01_conf0.52.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 1,
#   'problem_number': 180,
#   'type': '1',
#   'answer': '9'},
#  '라이트쎈 중등수학 1-1 - 11_section_02_conf0.51.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_02_conf0.51.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 2,
#   'problem_number': 178,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 11_section_03_conf0.50.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_03_conf0.50.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 3,
#   'problem_number': 181,
#   'type': '1',
#   'answer': '6'},
#  '라이트쎈 중등수학 1-1 - 11_section_04_conf0.45.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_04_conf0.45.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 4,
#   'problem_number': 182,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 11_section_05_conf0.36.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_05_conf0.36.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 5,
#   'problem_number': 179,
#   'type': '1',
#   'answer': '[1,2,3,6,6]'},
#  '라이트쎈 중등수학 1-1 - 11_section_06_conf0.31.jpg': {'file': '라이트쎈 중등수학 1-1 - 11_section_06_conf0.31.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 11,
#   'section_number': 6,
#   'problem_number': 183,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 12_section_00_conf0.75.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_00_conf0.75.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 0,
#   'problem_number': 191,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 12_section_01_conf0.71.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_01_conf0.71.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 1,
#   'problem_number': 188,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 12_section_02_conf0.62.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_02_conf0.62.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 2,
#   'problem_number': 187,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 12_section_03_conf0.55.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_03_conf0.55.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 3,
#   'problem_number': 186,
#   'type': '1',
#   'answer': '12'},
#  '라이트쎈 중등수학 1-1 - 12_section_04_conf0.52.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_04_conf0.52.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 4,
#   'problem_number': 185,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 12_section_05_conf0.49.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_05_conf0.49.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 5,
#   'problem_number': 189,
#   'type': '1',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 12_section_06_conf0.45.jpg': {'file': '라이트쎈 중등수학 1-1 - 12_section_06_conf0.45.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 12,
#   'section_number': 6,
#   'problem_number': 190,
#   'type': '1',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 13_section_00_conf0.73.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_00_conf0.73.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 0,
#   'problem_number': 197,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 13_section_01_conf0.72.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_01_conf0.72.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 1,
#   'problem_number': 193,
#   'type': '1',
#   'answer': '210'},
#  '라이트쎈 중등수학 1-1 - 13_section_02_conf0.72.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_02_conf0.72.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 2,
#   'problem_number': 195,
#   'type': '0',
#   'answer': '[1,4]'},
#  '라이트쎈 중등수학 1-1 - 13_section_03_conf0.68.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_03_conf0.68.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 3,
#   'problem_number': 196,
#   'type': '1',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 13_section_04_conf0.67.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_04_conf0.67.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 4,
#   'problem_number': 192,
#   'type': '1',
#   'answer': '[1,2,4]'},
#  '라이트쎈 중등수학 1-1 - 13_section_05_conf0.60.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_05_conf0.60.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 5,
#   'problem_number': 194,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 13_section_06_conf0.45.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_06_conf0.45.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 6,
#   'problem_number': 198,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 13_section_07_conf0.42.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_07_conf0.42.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 7,
#   'problem_number': 195,
#   'type': '0',
#   'answer': '[1,4]'},
#  '라이트쎈 중등수학 1-1 - 13_section_08_conf0.31.jpg': {'file': '라이트쎈 중등수학 1-1 - 13_section_08_conf0.31.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 13,
#   'section_number': 8,
#   'problem_number': 196,
#   'type': '1',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 14_section_00_conf0.73.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_00_conf0.73.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 0,
#   'problem_number': 201,
#   'type': '1',
#   'answer': '810'},
#  '라이트쎈 중등수학 1-1 - 14_section_01_conf0.66.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_01_conf0.66.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 1,
#   'problem_number': 205,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 14_section_02_conf0.63.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_02_conf0.63.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 2,
#   'problem_number': 200,
#   'type': '1',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 14_section_03_conf0.55.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_03_conf0.55.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 3,
#   'problem_number': 204,
#   'type': '[1:1, 2:1]',
#   'answer': '[1:7, 2:14]'},
#  '라이트쎈 중등수학 1-1 - 14_section_04_conf0.51.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_04_conf0.51.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 4,
#   'problem_number': 203,
#   'type': '0',
#   'answer': '1'},
#  '라이트쎈 중등수학 1-1 - 14_section_05_conf0.50.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_05_conf0.50.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 5,
#   'problem_number': 202,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 14_section_06_conf0.35.jpg': {'file': '라이트쎈 중등수학 1-1 - 14_section_06_conf0.35.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 14,
#   'section_number': 6,
#   'problem_number': 199,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 15_section_00_conf0.75.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_00_conf0.75.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 0,
#   'problem_number': 211,
#   'type': '1',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 15_section_01_conf0.72.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_01_conf0.72.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 1,
#   'problem_number': 207,
#   'type': '1',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 15_section_02_conf0.69.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_02_conf0.69.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 2,
#   'problem_number': 212,
#   'type': '1',
#   'answer': '6'},
#  '라이트쎈 중등수학 1-1 - 15_section_03_conf0.67.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_03_conf0.67.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 3,
#   'problem_number': 206,
#   'type': '1',
#   'answer': '[24,40,48]'},
#  '라이트쎈 중등수학 1-1 - 15_section_04_conf0.66.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_04_conf0.66.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 4,
#   'problem_number': 210,
#   'type': '0',
#   'answer': '4'},
#  '라이트쎈 중등수학 1-1 - 15_section_05_conf0.58.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_05_conf0.58.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 5,
#   'problem_number': 209,
#   'type': '0',
#   'answer': '5'},
#  '라이트쎈 중등수학 1-1 - 15_section_06_conf0.52.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_06_conf0.52.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 6,
#   'problem_number': 208,
#   'type': '0',
#   'answer': '2'},
#  '라이트쎈 중등수학 1-1 - 15_section_07_conf0.28.jpg': {'file': '라이트쎈 중등수학 1-1 - 15_section_07_conf0.28.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 15,
#   'section_number': 7,
#   'problem_number': 212,
#   'type': '1',
#   'answer': '6'},
#  '라이트쎈 중등수학 1-1 - 16_section_00_conf0.64.jpg': {'file': '라이트쎈 중등수학 1-1 - 16_section_00_conf0.64.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 16,
#   'section_number': 0,
#   'problem_number': 215,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 16_section_01_conf0.62.jpg': {'file': '라이트쎈 중등수학 1-1 - 16_section_01_conf0.62.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 16,
#   'section_number': 1,
#   'problem_number': 217,
#   'type': '0',
#   'answer': '3'},
#  '라이트쎈 중등수학 1-1 - 16_section_02_conf0.50.jpg': {'file': '라이트쎈 중등수학 1-1 - 16_section_02_conf0.50.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 16,
#   'section_number': 2,
#   'problem_number': 213,
#   'type': '1',
#   'answer': '90'},
#  '라이트쎈 중등수학 1-1 - 16_section_03_conf0.43.jpg': {'file': '라이트쎈 중등수학 1-1 - 16_section_03_conf0.43.jpg',
#   'book': '라이트쎈 중등수학 1-1',
#   'page': 16,
#   'section_number': 3,
#   'problem_number': 215,
#   'type': '0',
#   'answer': '3'}}

# %%
import os
import unicodedata
import re

def clean_string(s):
    """문자열 정제: Unicode 정규화, 공백 제거, invisible char 제거, 소문자 변환"""
    s = unicodedata.normalize("NFC", s)
    s = re.sub(r"\s+", "", s)  # 공백 제거
    s = re.sub(r"[\u200b\u200c\u200d\uFEFF]", "", s)  # invisible char 제거
    return s.lower()

def process_annotations(base_dir, annotation_dict, source_name):
    results = []
    for fname in os.listdir(base_dir):
        if not fname.lower().endswith(".jpg"):
            continue
        
        fname_clean = clean_string(fname)

        # annotation_dict에서 file 값과 fname_clean 비교
        matched = None
        for key, info in annotation_dict.items():
            file_value = info.get("file", "")
            file_clean = clean_string(file_value)
            if file_clean == fname_clean:
                matched = info
                break

        if not matched:
            print(f"⚠️ 매칭 실패: {fname} (annotation에 file이 없음)")
            continue

        image_path = os.path.join(base_dir, fname)

        results.append({
            "source": source_name,
            "book": matched["book"],
            "page": matched["page"],
            "problem_number": matched["problem_number"],
            "type": matched["type"],
            "answer": matched["answer"],
        })
    return results

# %%
results = []
results.extend(process_annotations("../../images/LLM_annotation", ann1, "LLM_annotation"))
