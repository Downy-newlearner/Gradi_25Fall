# %%
import os
import re

folder_path = "page_number"
output_file = "page_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

def natural_key(text):
    """파일명 안의 숫자를 기준으로 자연 정렬"""
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r'(\d+)', text)]

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

# 자연 정렬 적용
files.sort(key=natural_key)

# txt로 저장
with open(output_file, "w", encoding="utf-8") as f:
    for filename in files:
        f.write(filename + ", \n")

print(f"✅ 자연 정렬 기준으로 '{output_file}' 생성 완료!")
# Out:
# ✅ 자연 정렬 기준으로 'page_number.txt' 생성 완료!

# %%
import os
import re

folder_path = "problem_number"
output_file = "problem_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

def natural_key(text):
    """파일명 안의 숫자를 기준으로 자연 정렬"""
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r'(\d+)', text)]

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

# 자연 정렬 적용
files.sort(key=natural_key)

# txt로 저장
with open(output_file, "w", encoding="utf-8") as f:
    for filename in files:
        f.write(filename + ", \n")

print(f"✅ 자연 정렬 기준으로 '{output_file}' 생성 완료!")
# Out:
# ✅ 자연 정렬 기준으로 'problem_number.txt' 생성 완료!

# %%
import os
import re

folder_path = "page_number"
output_file = "page_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

print(f"📂 총 {len(files)}개의 이미지 파일이 발견되었습니다.")
# Out:
# 📂 총 168개의 이미지 파일이 발견되었습니다.

# %%
import os
import re

folder_path = "problem_number"
output_file = "problem_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

print(f"📂 총 {len(files)}개의 이미지 파일이 발견되었습니다.")
# Out:
# 📂 총 317개의 이미지 파일이 발견되었습니다.

# %%
import os
import re

folder_path = "page_number"
output_file = "page_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

# 파일 개수 출력
print(f"✅ 자연 정렬 기준으로 '{output_file}' 생성 완료!")
print(f"📂 총 {len(files)}개의 이미지 파일이 발견되었습니다.")

# page_number.txt의 라인 수 출력
with open(output_file, "r", encoding="utf-8") as f:
    line_count = sum(1 for _ in f)

print(f"📝 '{output_file}'에는 총 {line_count}개의 문장이 있습니다.")
# Out:
# ✅ 자연 정렬 기준으로 'page_number.txt' 생성 완료!
# 📂 총 168개의 이미지 파일이 발견되었습니다.
# 📝 'page_number.txt'에는 총 168개의 문장이 있습니다.

# %%
import os
import re

folder_path = "problem_number"
output_file = "problem_number.txt"
image_extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

# 폴더 내 이미지 파일만 추출
files = [
    f for f in os.listdir(folder_path)
    if os.path.splitext(f)[1].lower() in image_extensions
]

# 파일 개수 출력
print(f"✅ 자연 정렬 기준으로 '{output_file}' 생성 완료!")
print(f"📂 총 {len(files)}개의 이미지 파일이 발견되었습니다.")

# page_number.txt의 라인 수 출력
with open(output_file, "r", encoding="utf-8") as f:
    line_count = sum(1 for _ in f)

print(f"📝 '{output_file}'에는 총 {line_count}개의 문장이 있습니다.")
# Out:
# ✅ 자연 정렬 기준으로 'problem_number.txt' 생성 완료!
# 📂 총 317개의 이미지 파일이 발견되었습니다.
# 📝 'problem_number.txt'에는 총 317개의 문장이 있습니다.
